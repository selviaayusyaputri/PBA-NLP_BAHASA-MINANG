# %% [markdown]
# <a href="https://colab.research.google.com/github/selviaayusyaputri/PBA-NLP_BAHASA-MINANG/blob/main/Bahasa_Minangg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
{
    "indonesia": [
        "makan", "minum", "pergi", "datang", "tidur", "bangun", "berlari", "berjalan", "melihat", "mendengar",
        "bicara", "duduk", "berdiri", "senyum", "tertawa", "menangis", "belajar", "mengajar", "menulis", "membaca",
        "rumah", "sekolah", "kantor", "pasar", "warung", "kamar", "meja", "kursi", "jendela", "pintu",
        "ayah", "ibu", "adik", "kakak", "teman", "guru", "murid", "tetangga", "anak", "istri",
        "suami", "nenek", "kakek", "keluarga", "orang", "perempuan", "laki-laki", "pakai", "buka", "tutup",
        "masuk", "keluar", "naik", "turun", "ambil", "taruh", "lempar", "tangkap", "tolong", "maaf",
        "iya", "tidak", "mau", "bisa", "harus", "boleh", "sudah", "belum", "lagi", "sedang",
        "sore", "pagi", "siang", "malam", "hari", "bulan", "tahun", "kemarin", "besok", "sekarang",
        "air", "api", "tanah", "udara", "hujan", "panas", "dingin", "gelap", "terang", "cuaca",
        "ikan", "ayam", "sapi", "kerbau", "kucing", "anjing", "burung", "ular", "kuda", "bebek",
        "rendang", "sate", "gulai", "nasi", "lontong", "sayur", "buah", "jeruk", "pisang", "mangga",
        "mobil", "motor", "sepeda", "jalan", "jembatan", "gunung", "laut", "sungai", "danau", "pantai",
        "baju", "celana", "sepatu", "topi", "kaos", "jaket", "payung", "tas", "kaca", "cermin",
        "uang", "emas", "perak", "barang", "harga", "murah", "mahal", "jual", "beli", "tawar",
        "kerja", "libur", "cuti", "gaji", "bos", "pegawai", "rekan", "rapat", "proyek",
        "main", "lari", "bola", "layang", "kelereng", "gasing", "petak", "gambar", "nonton", "film",
        "dokter", "perawat", "sakit", "obat", "rumah sakit", "puskesmas", "klinik", "demam", "flu", "batuk",
        "hati", "otak", "mata", "telinga", "hidung", "mulut", "gigi", "tangan", "kaki", "perut", "ya ampun", "tambah macam", "apa kabar", "berapa itu", "kapan tiba", "sudah makan?",
        "enak sekali", "indah sekali", "apa itu", "apa ini", "siapa itu", "pergi kemana",
        "berhenti di sini", "tidak ada uang kecil", "air hangat satu", "berapa semuanya",
        "ke sinilah", "pesan empat porsi", "bungkus satu", "sulit banget", "bisa kurang?",
        "berapa pasnya", "kurang sedikit", "lagi apa?", "aku ikut dong", "dari seberang",
        "hati-hati ya", "pergi ke pernikahan", "terserah", "nanti dia marah", "kenapa aku terus?",
        "pinjam sendal ya", "cari di mana lagi?", "aku ngantuk banget", "aku kekenyangan",
        "merah", "biru", "hijau", "kuning", "hitam", "putih", "besar", "kecil", "tinggi", "pendek",
        "cepat", "lambat", "kuat", "lemah", "pintar", "bodoh", "kaya", "miskin", "bersih", "kotor",
        "panjang", "lebar", "dalam", "dangkal", "berat", "ringan", "keras", "lembut", "kasar", "halus",
        "pedas", "manis", "asam", "asin", "pahit", "segar", "busuk", "hangat", "sejuk", "lembab",
        "terbuka", "tertutup", "penuh", "kosong", "asing", "akrab", "biasa", "aneh", "sama", "beda",
        "bebas", "terikat", "sendiri", "bersama", "nyata", "maya", "mungkin", "pasti", "sering", "jarang",
        "selalu", "tidak pernah", "kadang-kadang", "semua", "beberapa", "tidak ada", "setiap", "banyak", "sedikit",
        "lebih", "kurang", "paling", "sama sekali", "agak", "cukup", "terlalu", "sangat", "sekali", "benar",
        "salah", "baik", "buruk", "bagus", "jelek", "indah", "cantik", "ganteng", "tampan", "jelas", "samar",
        "mudah", "sulit", "sederhana", "rumit", "lurus", "bengkok", "tajam", "tumpul",
        "depan", "belakang", "atas", "bawah", "kanan", "kiri", "dalam", "luar", "dekat", "jauh",
        "sini", "situ", "sana", "mana", "dimana", "kemana", "dari mana", "ke mana", "dengan siapa", "mengapa",
        "kapan", "berapa", "yang mana", "bagaimana", "apa", "siapa", "milik siapa", "tentang apa", "untuk apa", "kenapa",
        "apakah", "mungkinkah", "benarkah", "sungguh", "betul", "memang", "seperti", "seolah-olah", "kira-kira", "hampir",
        "segera", "nanti", "sebentar", "lama", "sejak", "hingga", "sampai", "ketika", "waktu", "saat",
        "sebelum", "sesudah", "setelah", "lusa", "minggu lalu", "minggu depan", "bulan lalu", "bulan depan", "tahun lalu", "tahun depan",
        "pada", "di", "ke", "dari", "dengan", "tanpa", "untuk",
        "oleh", "karena", "sebab", "akibat", "agar", "supaya", "jika", "kalau", "bila", "apabila",
        "meskipun", "walaupun", "biarpun", "namun", "tetapi", "akan tetapi", "sedangkan", "sementara", "padahal",
        "sebaliknya", "justru", "malah", "bahkan", "lagi pula", "selain itu", "tambahan lagi", "lebih lanjut", "akhirnya",
        "kesimpulannya", "jadi", "oleh karena itu", "maka", "dengan demikian", "misalnya", "contohnya", "yakni",
        "yaitu", "adalah", "merupakan", "ialah", "bahwa", "yang", "ini", "itu", "tersebut", "demikian",
        "hal", "perkara", "masalah", "urusan", "keadaan", "situasi", "kondisi", "cara", "metode", "proses",
        "hasil", "dampak", "pengaruh", "tujuan", "maksud", "arti", "makna", "definisi", "penjelasan",
        "lelah", "lapar", "haus", "marah", "sedih", "bahagia", "takut", "berani", "jujur", "bohong",
        "sakit", "sehat", "dingin", "panas", "lembab", "kering", "basah", "sempit", "luas", "ramai",
        "sepi", "bersih", "kotor", "rajin", "malas", "cerdik", "bodoh", "kaya", "miskin", "muda", "tua",
        "baru", "lama", "rusak", "bagus", "jelek", "asli", "palsu", "mudah", "sulit", "cepat", "lambat",
        "satu", "dua", "tiga", "empat", "lima", "enam", "tujuh", "delapan", "sembilan", "sepuluh",
        "nol", "puluh", "ratus", "ribu", "juta", "milyar", "pertama", "kedua", "ketiga", "terakhir",
        "utara", "selatan", "timur", "barat", "tenggara", "barat daya", "timur laut", "barat laut",
        "atas", "bawah", "depan", "belakang", "kanan", "kiri", "samping", "tengah", "ujung", "pangkal",
        "luar", "dalam", "sekitar", "antara", "sepanjang", "menuju", "melalui", "di atas", "di bawah", "di samping","ke", "akan"
    ],
    "minang": [
        "makan", "minum", "pai", "datang", "baradu", "bangun", "babaliak", "banalan", "maliek", "mangaruik",
        "babicaro", "duduak", "tagak", "sanyuik", "tagakak", "manangih", "mambalajari", "mangajarkan", "manulih", "mambaco",
        "rumah", "sakolah", "kantor", "pasa", "waruang", "kamar", "meja", "kursi", "jandela", "pintu",
        "apak", "mak", "adik", "uni", "kawan", "guru", "murid", "tetanggo", "anak", "bini",
        "sumando", "ndak", "apek", "urang rumah", "urang", "padusi", "laki-laki", "mamakai", "mambuka", "manutuik",
        "masuak", "kelua", "naik", "turun", "mangambiek", "manaruah", "mambuang", "mangangka", "tolong", "maaf",
        "iyo", "kandak", "bisa", "harus", "boleh", "alun", "balum", "lai", "tengah",
        "sore", "pagi", "siang", "malam", "hari", "bulan", "tahun", "kamaren", "esok", "kiniko",
        "aia", "api", "tanah", "udaro", "hujan", "panas", "dingin", "galap", "tarang", "cuaco",
        "ikan", "ayam", "sapi", "kabau", "kuciang", "anjing", "buruang", "ular", "kudo", "itik",
        "randang", "sate", "gulai", "nasi", "lontong", "sayua", "buah", "jeruk", "pisang", "mangga",
        "mobiak", "montor", "sapeda", "jalan", "jambatan", "gunuang", "lautan", "batang aia", "danau", "pantai",
        "baju", "calano", "sapatu", "deta", "kaos", "jaket", "payuang", "tas", "kaca", "cermin",
        "uang", "amas", "perak", "barang", "harga", "murah", "mahal", "juo", "bali", "tawar",
        "karajo", "libua", "cuti", "gaji", "bos", "pegawai", "rakan", "rapek", "proyek",
        "main", "larian", "balo", "layang", "kalering", "gasiang", "petak umpet", "gambar", "nonton", "filem",
        "dokter", "parawat", "sakit", "obat", "rumah sakit", "puskesmas", "klinik", "demam", "flu", "batuek",
        "hati", "otak", "mato", "talingo", "idung", "mulut", "gigi", "tangan", "kaki", "parut", "onde mande", "tambuah ciek", "baa kaba?", "bara tu ni?", "bilo tibo?",
        "alah makan?", "lamak bana", "rancak bana", "a ko", "a ni", "sia tu?", "pai kama tu?",
        "siko ciek", "nda ado pitiah ketek", "aiaa angek ciek", "bara sadonyo?",
        "siko lah", "makan ampek", "bungkuih ciek", "kamari payah", "lai bisa kurang?",
        "bara pasnyo?", "kuranglah saketek", "manga tu?", "pai awak ciek",
        "dari subaliak nagari tan", "elok-elok yo", "pai baralek", "suko-suko ang lah",
        "berang paja tu beko", "awak tarui se mah", "pinjam awak tarompa yo",
        "dima ka dicari lai koh?", "ambo takantuak bana", "kakanyangan ambo",
        "merah", "biru", "hijau", "kuniang", "itam", "putiah", "gadang", "ketek", "tinggi", "pendek",
        "capek", "lambek", "kuek", "lema", "cadiak", "boduah", "kayo", "miskin", "barasiah", "kumuah",
        "panjang", "leba", "dalam", "dangkal", "barek", "ringan", "kareh", "lembut", "kasa", "haluih",
        "padeh", "manih", "asam", "asin", "pait", "sago", "busuak", "angek", "sejuak", "lambok",
        "tabukak", "tatutuik", "panuah", "kosong", "asing", "akrab", "biaso", "aneh", "samo", "beda",
        "bebas", "taikek", "surang", "basamo", "nyato", "mayo", "mungkin", "pasti", "acok", "jarang",
        "salalu", "indak pernah", "kadang-kadang", "sadonyo", "beberapa", "indak ado", "tiok", "banyak", "saketek",
        "labiah", "kurang", "paliang", "samo sakali", "agak", "cukuik", "talalu", "sangat", "sakali", "bana",
        "salah", "elok", "buruak", "rancak", "jelek", "ganteng", "tampan", "jaleh", "samar",
        "mudah", "payah", "sederhana", "rumik", "lurus", "bengkok", "tajam", "tumpua",
        "depan", "balakang", "ateh", "bawah", "kanan", "kida", "dalam", "lua", "dakek", "jauah",
        "siko", "situ", "sinan", "mano", "dima", "kama", "dari mano", "ka mano", "jo sia", "manga",
        "bilo", "bara", "nan mano", "baa", "a", "sia", "punyo sia", "tantang a", "untuak a", "manga",
        "apokah", "mungkinkah", "benarkah", "sungguah", "batua", "memang", "sarupo", "seolah-olah", "agaknyo", "hampia",
        "sacepatnyo", "nantinyo", "sakedik", "lamo", "sajak", "hinggo", "sampai", "kutiko", "waktu", "saaik",
        "sabalum", "sasudah", "satelah", "kiniko", "kamaren", "esok", "luso", "minggu lalu", "minggu depan", "bulan lalu",
        "bulan depan", "tahun lalu", "tahun depan", "pado", "di", "ka", "dari", "jo", "tanpa", "untuak",
        "dek", "karano", "sabab", "akibat", "agar", "supayo", "jiko", "kok", "bilo", "apobilo",
        "meskipun", "walaupun", "biapun", "namun", "tapi", "akan tetapi", "sadangkan", "samentara", "padahal",
        "sabaliknyo", "justru", "malah", "bahkan", "lai pulo", "salain itu", "tambahan lai", "labiah lanjuik", "akhirnyo",
        "kasimpulannyo", "jadi", "dek karano itu", "mako", "jo demikian", "sarupo", "misalnyo", "contohnyo", "yakni",
        "yaitu", "adolah", "merupakan", "ialah", "bahwa", "nan", "iko", "itu", "tersebut", "demikian",
        "hal", "perkara", "masalah", "urusan", "kaadaan", "situasi", "kondisi", "caro", "metode", "proses",
        "hasil", "akibat", "dampak", "pengaruh", "tujuan", "maksud", "arti", "makna", "definisi", "panjalehan",
        "litak", "lapueh", "haus", "berang", "cameh", "galak", "takuk", "barani", "juju", "duto",
        "sakeik", "sahe", "dingin", "panas", "lambok", "kariang", "basah", "sampik", "luweh", "rame",
        "sunyi", "barasiah", "kumuah", "rajin", "maleh", "cadiak", "boduah", "kayo", "miskin", "mudo", "tuo",
        "baru", "lamo", "rusak", "rancak", "jelek", "asli", "palsu", "mudah", "payah", "capek", "lambek",
        "ciek", "duo", "tigo", "ampek", "limo", "anam", "tujuah", "salapan", "sambilan", "sapuluah",
        "nol", "puluh", "ratuih", "ribu", "juta", "miliyar", "partamo", "kadu", "katigo", "tarakhir",
        "utara", "selatan", "timur", "barat", "tenggara", "barat daya", "timur laut", "barat laut",
        "ateh", "bawah", "depan", "balakang", "kanan", "kida", "sampiang", "tangah", "ujuang", "pangkal",
        "lua", "dalam", "sakitar", "antaro", "sapanjang", "manuju", "malalui", "di ateh", "di bawah", "di sampiang", "ka", "nak"
    ]
}
# Out:
# {'indonesia': ['makan',
#   'minum',
#   'pergi',
#   'datang',
#   'tidur',
#   'bangun',
#   'berlari',
#   'berjalan',
#   'melihat',
#   'mendengar',
#   'bicara',
#   'duduk',
#   'berdiri',
#   'senyum',
#   'tertawa',
#   'menangis',
#   'belajar',
#   'mengajar',
#   'menulis',
#   'membaca',
#   'rumah',
#   'sekolah',
#   'kantor',
#   'pasar',
#   'warung',
#   'kamar',
#   'meja',
#   'kursi',
#   'jendela',
#   'pintu',
#   'ayah',
#   'ibu',
#   'adik',
#   'kakak',
#   'teman',
#   'guru',
#   'murid',
#   'tetangga',
#   'anak',
#   'istri',
#   'suami',
#   'nenek',
#   'kakek',
#   'keluarga',
#   'orang',
#   'perempuan',
#   'laki-laki',
#   'pakai',
#   'buka',
#   'tutup',
#   'masuk',
#   'keluar',
#   'naik',
#   'turun',
#   'ambil',
#   'taruh',
#   'lempar',
#   'tangkap',
#   'tolong',
#   'maaf',
#   'iya',
#   'tidak',
#   'mau',
#   'bisa',
#   'harus',
#   'boleh',
#   'sudah',
#   'belum',
#   'lagi',
#   'sedang',
#   'sore',
#   'pagi',
# ...

# %%
ind_to_min = dict(zip(data['indonesia'], data['minang']))
min_to_ind = dict(zip(data['minang'], data['indonesia']))

# %%
def translate_id_to_minang(sentence):
    words = sentence.lower().split()
    translated = []
    for word in words:
        if word in ind_to_min:
            translated.append(ind_to_min[word])
        else:
            translated.append(f"[{word}]")
    return ' '.join(translated)

def translate_minang_to_id(sentence):
    words = sentence.lower().split()
    translated = []
    for word in words:
        if word in min_to_ind:
            translated.append(min_to_ind[word])
        else:
            translated.append(f"[{word}]")
    return ' '.join(translated)

# %%
import gradio as gr

def translate_interface(text, direction):
    if direction == "id-to-minang":
        return translate_id_to_minang(text)
    else:
        return translate_minang_to_id(text)

# %%
iface = gr.Interface(
    fn=translate_interface,
    inputs=[
gr.Textbox(label=" Masukkan Kalimat", placeholder="Contoh: Saya pergi ke pasar", lines=2),
        gr.Radio(
            choices=["id-to-minang", "minang-to-id"],
            label="Arah Terjemahan",
            value="id-to-minang"
        )
    ],
    outputs=gr.Textbox(label="Hasil Terjemahan"),
    title="Penerjemah Bahasa Indonesia ↔ Minang",
    description="Masukkan kalimat dalam Bahasa Indonesia atau Minang untuk diterjemahkan.",
    theme=gr.themes.soft,

        flagging_mode="manual",
    flagging_callback=gr.CSVLogger(),

    css="""
         .gradio-container {
            max-width: 720px !important;
            margin: 40px auto !important;
            border-radius: 20px;
            padding: 32px 40px;
            box-shadow: 0 16px 40px rgba(0, 0, 0, 0.1);
            background: linear-gradient(to right, #fbfff0, #fff);
            font-family: 'Segoe UI', sans-serif;
        }
        .gr-button {
            font-weight: 600;
            width: 100%;
            background-color: #e67e22 !important;
            color: white !important;
            padding: 0.9rem 1.6rem;
             border-radius: 16px !important;
        box-shadow: 0 4px 14px rgba(230, 126, 34, 0.4);
            transition: all 0.3s ease-in-out;


        }

        .gr-button:hover {
            background-color: #d35400 !important;
            transform: scale(1.03);
        }

        .gr-input, .gr-textbox, .gr-radio {
            border-radius: 12px !important;
        }


        h1, h2 {
            text-align: center;
            color: #e67e22;
        }

        label {
            font-weight: 600 !important;
            color: #333 !important;
        }

        .gr-flag-button {
            background-color: transparent !important;
            border: 1.5px dashed #e67e22 !important;
            color: #e67e22 !important;
            border-radius: 12px !important;
            transition: all 0.2s ease-in-out;
        }

        .gr-flag-button:hover {
            background-color: #fef5ec !important;
            cursor: pointer;
        }
    """
)

iface.launch()
# Out:
# /usr/local/lib/python3.11/dist-packages/gradio/blocks.py:1156: UserWarning: Theme should be a class loaded from gradio.themes
#   warnings.warn("Theme should be a class loaded from gradio.themes")
# It looks like you are running Gradio on a hosted a Jupyter notebook. For the Gradio app to work, sharing must be enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://3c7839be98e85d7fd2.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# ...

# %%
iface.launch()
# Out:
# Rerunning server... use `close()` to stop if you need to change `launch()` parameters.
# ----
# It looks like you are running Gradio on a hosted a Jupyter notebook. For the Gradio app to work, sharing must be enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://3c7839be98e85d7fd2.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://3c7839be98e85d7fd2.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
pairs = list(zip(data["indonesia"], data["minang"]))
